# %%
# !pip install pillow 

#needed library

# %%
letters = 'ABJDRSXTEGKLZNHUV'

# %%
numbers = '0123456789'

# %%
import random

# %%
x = range(100)

# %%
from PIL import Image, ImageFont, ImageDraw
im = Image.open("bb.jpg")
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=696x348 at 0x7F2F82DA8640>

# %%
latin_numbers_dict={"0":"٠","1":"١","2":"٢","3":"٣","4":"٤","5":"٥","6":"٦","7":"٧","8":"٨","9":"٩"}
arabic_numbers_dict={"٠":"0","١":"1","٢":"2","٣":"3","٤":"4","٥":"5","٦":"6","٧":"7","٨":"8","٩":"9"}
letters = ["ا", "ب", "ح", "د", "ر", "س", "ص", "ط", "ع", "ق", "ك", "ل", "م", "ن", "ه", "و" ,"ى"] 
# Lletters = {"ا" ,"":"ب", "":"ح" ,"":"د" ,"":"ر","" :"س","" :"ص","" :"ط","":"ع","" :"ق","" :"ك","" :"ل","" :"م","" :"ن","":"ه","" :"و","a" ,"ى":"v"}
arabic_letters_dict = {"ا":"A","ب":"B","ح":"J","د":"D","ر":"R","س":"S","ص":"X","ط":"T","ع":"E","ق":"G","ك":"K","ل":"L","م":"Z","ن":"N","ه":"H","و":"U","ى":"V"}
special_letters = ''
numbers = '٠١٢٣٤٥٦٧٨٩'
latin_digits = []
arabic_rand_numb = []
alphabets = []
arabic_rand_letters = []
import random
for i in range(4):
    arabic_rand_numb.append(random.choice(numbers))
    latin_digits.append((arabic_numbers_dict[arabic_rand_numb[i]]))

for i in range(3):
    arabic_rand_letters.append(random.choice(letters))
    alphabets.append((arabic_letters_dict[arabic_rand_letters[i]]))



print(arabic_rand_numb)
print(latin_digits)
print(arabic_rand_letters)
print(alphabets)


from PIL import Image, ImageFont, ImageDraw
im = Image.open("bb.jpg")
d = ImageDraw.Draw(im)
font = ImageFont.truetype("arial.ttf",150)





tex = ("".join(map(str, arabic_rand_numb)))
d.text((30,30),tex,fill=("black"),font =font)


font = ImageFont.truetype("arial.ttf",140)
tex = ("".join(map(str, latin_digits)))

d.text((30,170),tex,fill=("black"),font =font)


font = ImageFont.truetype("arial.ttf",80)
# tex = (''.join(map(str, arabic_rand_letters)))

x =[370,440,495]
y = 30


for i in range(3):
    d.text((x[i],30),arabic_rand_letters[i],fill=("black"),font =font)




font = ImageFont.truetype("arial.ttf",90)
tex = (''.join(map(str, alphabets)))

d.text((375,200),tex,fill=("black"),font =font)
im.save("drawn_grid.png")





im = Image.open('drawn_grid.png')
display(im)
# Out:
# ['٧', '٤', '٥', '٩']
# ['7', '4', '5', '9']
# ['ر', 'ه', 'ق']
# ['R', 'H', 'G']
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=696x348 at 0x7F2F82D90FD0>
